# %% [markdown]
# # Mondo RD subset analysis

# %%
## Settings

mondo_path = "../../ontology/tmp/mondo_paper.db"
mappings_path = "../ontology/mappings/mondo.sssom.tsv"

oak_adapter = f"sqlite:{mondo_path}"

# %%
# Install Python packages
#!pip install upsetplot
# !pip install oaklib
# Out:
# Collecting oaklib
#   Using cached oaklib-0.6.6-py3-none-any.whl.metadata (9.2 kB)
# Collecting SPARQLWrapper (from oaklib)
#   Using cached SPARQLWrapper-2.0.0-py3-none-any.whl.metadata (2.0 kB)
# Collecting SQLAlchemy>=1.4.32 (from oaklib)
#   Using cached SQLAlchemy-2.0.30-cp311-cp311-macosx_11_0_arm64.whl.metadata (9.6 kB)
# Collecting airium>=0.2.5 (from oaklib)
#   Using cached airium-0.2.6-py3-none-any.whl.metadata (15 kB)
# Collecting appdirs>=1.4.4 (from oaklib)
#   Using cached appdirs-1.4.4-py2.py3-none-any.whl.metadata (9.0 kB)
# Collecting class-resolver>=0.4.2 (from oaklib)
#   Using cached class_resolver-0.4.3-py3-none-any.whl.metadata (13 kB)
# Collecting click (from oaklib)
#   Using cached click-8.1.7-py3-none-any.whl.metadata (3.0 kB)
# Collecting curies>=0.6.6 (from oaklib)
#   Using cached curies-0.7.9-py3-none-any.whl.metadata (9.3 kB)
# Collecting defusedxml<0.8.0,>=0.7.1 (from oaklib)
#   Using cached defusedxml-0.7.1-py2.py3-none-any.whl.metadata (32 kB)
# Collecting eutils>=0.6.0 (from oaklib)
#   Using cached eutils-0.6.0-py2.py3-none-any.whl.metadata (7.0 kB)
# Collecting funowl>=0.2.0 (from oaklib)
#   Using cached funowl-0.2.3-py3-none-any.whl.metadata (971 bytes)
# Collecting jsonlines<5.0.0,>=4.0.0 (from oaklib)
#   Using cached jsonlines-4.0.0-py3-none-any.whl.metadata (1.6 kB)
# Collecting kgcl-rdflib==0.5.0 (from oaklib)
#   Using cached kgcl_rdflib-0.5.0-py3-none-any.whl.metadata (1.0 kB)
# Collecting kgcl-schema<0.7.0,>=0.6.8 (from oaklib)
#   Using cached kgcl_schema-0.6.8-py3-none-any.whl.metadata (1.0 kB)
# Collecting linkml-renderer>=0.3.0 (from oaklib)
#   Using cached linkml_renderer-0.3.0-py3-none-any.whl.metadata (3.8 kB)
# Collecting linkml-runtime>=1.5.3 (from oaklib)
#   Using cached linkml_runtime-1.7.5-py3-none-any.whl.metadata (3.6 kB)
# Collecting ndex2<4.0.0,>=3.5.0 (from oaklib)
#   Using cached ndex2-3.8.0-py2.py3-none-any.whl.metadata (14 kB)
# Collecting networkx>=2.7.1 (from oaklib)
#   Using cached networkx-3.3-py3-none-any.whl.metadata (5.1 kB)
# Collecting ols-client>=0.1.1 (from oaklib)
#   Using cached ols_client-0.1.4-py3-none-any.whl.metadata (7.4 kB)
# Collecting ontoportal-client>=0.0.3 (from oaklib)
#   Using cached ontoportal_client-0.0.4-py3-none-any.whl.metadata (8.7 kB)
# Collecting prefixmaps>=0.1.2 (from oaklib)
#   Using cached prefixmaps-0.2.4-py3-none-any.whl.metadata (7.3 kB)
# Collecting pronto>=2.5.0 (from oaklib)
#   Using cached pronto-2.5.7-py2.py3-none-any.whl.metadata (9.5 kB)
# Collecting pydantic (from oaklib)
#   Using cached pydantic-2.7.1-py3-none-any.whl.metadata (107 kB)
# Collecting pysolr<4.0.0,>=3.9.0 (from oaklib)
#   Using cached pysolr-3.9.0-py2.py3-none-any.whl
# Collecting pystow>=0.5.0 (from oaklib)
#   Using cached pystow-0.5.4-py3-none-any.whl.metadata (8.9 kB)
# Collecting ratelimit>=2.2.1 (from oaklib)
#   Using cached ratelimit-2.2.1-py3-none-any.whl
# Collecting requests-cache<2.0.0,>=1.0.1 (from oaklib)
#   Using cached requests_cache-1.2.0-py3-none-any.whl.metadata (9.9 kB)
# Collecting semsql>=0.3.1 (from oaklib)
#   Using cached semsql-0.3.3-py3-none-any.whl.metadata (9.5 kB)
# Collecting sssom<0.5.0,>=0.4.4 (from oaklib)
#   Using cached sssom-0.4.9-py3-none-any.whl.metadata (4.1 kB)
# Collecting tenacity<9.0.0,>=8.2.3 (from oaklib)
#   Using cached tenacity-8.3.0-py3-none-any.whl.metadata (1.2 kB)
# Collecting pytrie (from curies>=0.6.6->oaklib)
#   Using cached PyTrie-0.4.0-py3-none-any.whl.metadata (1.6 kB)
# Collecting requests (from curies>=0.6.6->oaklib)
#   Using cached requests-2.31.0-py3-none-any.whl.metadata (4.6 kB)
# Collecting lxml (from eutils>=0.6.0->oaklib)
#   Using cached lxml-5.2.2-cp311-cp311-macosx_10_9_universal2.whl.metadata (3.4 kB)
# Collecting pytz (from eutils>=0.6.0->oaklib)
#   Using cached pytz-2024.1-py2.py3-none-any.whl.metadata (22 kB)
# Collecting bcp47 (from funowl>=0.2.0->oaklib)
#   Using cached bcp47-0.1.0-py3-none-any.whl.metadata (2.0 kB)
# Collecting jsonasobj (from funowl>=0.2.0->oaklib)
#   Using cached jsonasobj-1.3.1-py3-none-any.whl.metadata (995 bytes)
# Collecting pyjsg>=0.11.6 (from funowl>=0.2.0->oaklib)
#   Using cached PyJSG-0.11.10-py3-none-any.whl.metadata (978 bytes)
# Collecting rdflib-shim (from funowl>=0.2.0->oaklib)
#   Using cached rdflib_shim-1.0.3-py3-none-any.whl.metadata (918 bytes)
# Collecting rdflib<8,>=6.2.0 (from funowl>=0.2.0->oaklib)
#   Using cached rdflib-7.0.0-py3-none-any.whl.metadata (11 kB)
# Collecting rfc3987 (from funowl>=0.2.0->oaklib)
#   Using cached rfc3987-1.3.8-py2.py3-none-any.whl.metadata (7.5 kB)
# Collecting attrs>=19.2.0 (from jsonlines<5.0.0,>=4.0.0->oaklib)
#   Using cached attrs-23.2.0-py3-none-any.whl.metadata (9.5 kB)
# Collecting lark>=1.1.2 (from kgcl-schema<0.7.0,>=0.6.8->oaklib)
#   Using cached lark-1.1.9-py3-none-any.whl.metadata (1.9 kB)
# Collecting deprecated (from linkml-runtime>=1.5.3->oaklib)
#   Using cached Deprecated-1.2.14-py2.py3-none-any.whl.metadata (5.4 kB)
# Collecting hbreader (from linkml-runtime>=1.5.3->oaklib)
#   Using cached hbreader-0.9.1-py3-none-any.whl.metadata (663 bytes)
# Collecting json-flattener>=0.1.9 (from linkml-runtime>=1.5.3->oaklib)
#   Using cached json_flattener-0.1.9-py3-none-any.whl.metadata (5.9 kB)
# Collecting jsonasobj2<2.dev0,>=1.0.4 (from linkml-runtime>=1.5.3->oaklib)
#   Using cached jsonasobj2-1.0.4-py3-none-any.whl.metadata (964 bytes)
# Collecting jsonschema>=3.2.0 (from linkml-runtime>=1.5.3->oaklib)
#   Using cached jsonschema-4.22.0-py3-none-any.whl.metadata (8.2 kB)
# Collecting prefixcommons>=0.1.12 (from linkml-runtime>=1.5.3->oaklib)
#   Using cached prefixcommons-0.1.12-py3-none-any.whl.metadata (2.0 kB)
# Collecting pyyaml (from linkml-runtime>=1.5.3->oaklib)
#   Using cached PyYAML-6.0.1-cp311-cp311-macosx_11_0_arm64.whl.metadata (2.1 kB)
# Requirement already satisfied: six in /Users/matentzn/ws/mondo/.venv/lib/python3.11/site-packages (from ndex2<4.0.0,>=3.5.0->oaklib) (1.16.0)
# Collecting ijson (from ndex2<4.0.0,>=3.5.0->oaklib)
#   Using cached ijson-3.2.3-cp311-cp311-macosx_11_0_arm64.whl.metadata (20 kB)
# Collecting requests-toolbelt (from ndex2<4.0.0,>=3.5.0->oaklib)
#   Using cached requests_toolbelt-1.0.0-py2.py3-none-any.whl.metadata (14 kB)
# Collecting urllib3>=1.16 (from ndex2<4.0.0,>=3.5.0->oaklib)
#   Using cached urllib3-2.2.1-py3-none-any.whl.metadata (6.4 kB)
# Collecting pandas (from ndex2<4.0.0,>=3.5.0->oaklib)
#   Using cached pandas-2.2.2-cp311-cp311-macosx_11_0_arm64.whl.metadata (19 kB)
# Collecting numpy (from ndex2<4.0.0,>=3.5.0->oaklib)
#   Using cached numpy-1.26.4-cp311-cp311-macosx_11_0_arm64.whl.metadata (114 kB)
# Collecting more-click (from ols-client>=0.1.1->oaklib)
#   Using cached more_click-0.1.2-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: typing-extensions in /Users/matentzn/ws/mondo/.venv/lib/python3.11/site-packages (from ontoportal-client>=0.0.3->oaklib) (4.11.0)
# Collecting chardet~=5.0 (from pronto>=2.5.0->oaklib)
#   Using cached chardet-5.2.0-py3-none-any.whl.metadata (3.4 kB)
# Collecting fastobo~=0.12.2 (from pronto>=2.5.0->oaklib)
#   Using cached fastobo-0.12.3-cp311-cp311-macosx_11_0_arm64.whl.metadata (6.3 kB)
# Requirement already satisfied: python-dateutil~=2.8 in /Users/matentzn/ws/mondo/.venv/lib/python3.11/site-packages (from pronto>=2.5.0->oaklib) (2.9.0.post0)
# Collecting annotated-types>=0.4.0 (from pydantic->oaklib)
#   Using cached annotated_types-0.6.0-py3-none-any.whl.metadata (12 kB)
# Collecting pydantic-core==2.18.2 (from pydantic->oaklib)
#   Using cached pydantic_core-2.18.2-cp311-cp311-macosx_11_0_arm64.whl.metadata (6.5 kB)
# Collecting tqdm (from pystow>=0.5.0->oaklib)
#   Using cached tqdm-4.66.4-py3-none-any.whl.metadata (57 kB)
# Collecting cattrs>=22.2 (from requests-cache<2.0.0,>=1.0.1->oaklib)
#   Using cached cattrs-23.2.3-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: platformdirs>=2.5 in /Users/matentzn/ws/mondo/.venv/lib/python3.11/site-packages (from requests-cache<2.0.0,>=1.0.1->oaklib) (4.2.2)
# Collecting url-normalize>=1.4 (from requests-cache<2.0.0,>=1.0.1->oaklib)
#   Using cached url_normalize-1.4.3-py2.py3-none-any.whl.metadata (3.1 kB)
# Collecting SQLAlchemy-Utils<0.39.0,>=0.38.2 (from semsql>=0.3.1->oaklib)
#   Using cached SQLAlchemy_Utils-0.38.3-py3-none-any.whl.metadata (4.2 kB)
# Collecting deprecation<3.0.0,>=2.1.0 (from sssom<0.5.0,>=0.4.4->oaklib)
#   Using cached deprecation-2.1.0-py2.py3-none-any.whl.metadata (4.6 kB)
# Collecting importlib-resources<7.0.0,>=6.1.1 (from sssom<0.5.0,>=0.4.4->oaklib)
#   Using cached importlib_resources-6.4.0-py3-none-any.whl.metadata (3.9 kB)
# Collecting pansql>=0.0.1 (from pansql[pansql]>=0.0.1->sssom<0.5.0,>=0.4.4->oaklib)
#   Using cached pansql-0.0.1-py3-none-any.whl.metadata (3.6 kB)
# Collecting scipy[scipy] (from sssom<0.5.0,>=0.4.4->oaklib)
#   Using cached scipy-1.13.0-cp311-cp311-macosx_12_0_arm64.whl.metadata (60 kB)
# Collecting sssom-schema<0.16.0,>=0.15.2 (from sssom<0.5.0,>=0.4.4->oaklib)
#   Using cached sssom_schema-0.15.2-py3-none-any.whl.metadata (7.7 kB)
# Collecting validators>=0.20.0 (from sssom<0.5.0,>=0.4.4->oaklib)
#   Using cached validators-0.28.1-py3-none-any.whl.metadata (3.6 kB)
# Requirement already satisfied: packaging in /Users/matentzn/ws/mondo/.venv/lib/python3.11/site-packages (from deprecation<3.0.0,>=2.1.0->sssom<0.5.0,>=0.4.4->oaklib) (24.0)
# Collecting jsonschema-specifications>=2023.03.6 (from jsonschema>=3.2.0->linkml-runtime>=1.5.3->oaklib)
#   Using cached jsonschema_specifications-2023.12.1-py3-none-any.whl.metadata (3.0 kB)
# Collecting referencing>=0.28.4 (from jsonschema>=3.2.0->linkml-runtime>=1.5.3->oaklib)
#   Using cached referencing-0.35.1-py3-none-any.whl.metadata (2.8 kB)
# Collecting rpds-py>=0.7.1 (from jsonschema>=3.2.0->linkml-runtime>=1.5.3->oaklib)
#   Using cached rpds_py-0.18.1-cp311-cp311-macosx_11_0_arm64.whl.metadata (4.1 kB)
# WARNING: networkx 3.3 does not provide the extra 'networkx'
# Collecting tzdata>=2022.7 (from pandas->ndex2<4.0.0,>=3.5.0->oaklib)
#   Using cached tzdata-2024.1-py2.py3-none-any.whl.metadata (1.4 kB)
# WARNING: pansql 0.0.1 does not provide the extra 'pansql'
# Collecting pytest-logging<2016.0.0,>=2015.11.4 (from prefixcommons>=0.1.12->linkml-runtime>=1.5.3->oaklib)
#   Using cached pytest_logging-2015.11.4-py3-none-any.whl
# Collecting antlr4-python3-runtime~=4.9.3 (from pyjsg>=0.11.6->funowl>=0.2.0->oaklib)
#   Using cached antlr4_python3_runtime-4.9.3-py3-none-any.whl
# Collecting isodate<0.7.0,>=0.6.0 (from rdflib<8,>=6.2.0->funowl>=0.2.0->oaklib)
#   Using cached isodate-0.6.1-py2.py3-none-any.whl.metadata (9.6 kB)
# Collecting pyparsing<4,>=2.1.0 (from rdflib<8,>=6.2.0->funowl>=0.2.0->oaklib)
#   Using cached pyparsing-3.1.2-py3-none-any.whl.metadata (5.1 kB)
# Collecting charset-normalizer<4,>=2 (from requests->curies>=0.6.6->oaklib)
#   Using cached charset_normalizer-3.3.2-cp311-cp311-macosx_11_0_arm64.whl.metadata (33 kB)
# Collecting idna<4,>=2.5 (from requests->curies>=0.6.6->oaklib)
#   Using cached idna-3.7-py3-none-any.whl.metadata (9.9 kB)
# Collecting certifi>=2017.4.17 (from requests->curies>=0.6.6->oaklib)
#   Using cached certifi-2024.2.2-py3-none-any.whl.metadata (2.2 kB)
# Collecting wrapt<2,>=1.10 (from deprecated->linkml-runtime>=1.5.3->oaklib)
#   Using cached wrapt-1.16.0-cp311-cp311-macosx_11_0_arm64.whl.metadata (6.6 kB)
# Collecting sortedcontainers (from pytrie->curies>=0.6.6->oaklib)
#   Using cached sortedcontainers-2.4.0-py2.py3-none-any.whl.metadata (10 kB)
# Collecting rdflib-jsonld==0.6.1 (from rdflib-shim->funowl>=0.2.0->oaklib)
#   Using cached rdflib_jsonld-0.6.1-py2.py3-none-any.whl.metadata (3.4 kB)
# WARNING: scipy 1.13.0 does not provide the extra 'scipy'
# Collecting pytest>=2.8.1 (from pytest-logging<2016.0.0,>=2015.11.4->prefixcommons>=0.1.12->linkml-runtime>=1.5.3->oaklib)
#   Using cached pytest-8.2.0-py3-none-any.whl.metadata (7.5 kB)
# Collecting iniconfig (from pytest>=2.8.1->pytest-logging<2016.0.0,>=2015.11.4->prefixcommons>=0.1.12->linkml-runtime>=1.5.3->oaklib)
#   Using cached iniconfig-2.0.0-py3-none-any.whl.metadata (2.6 kB)
# Collecting pluggy<2.0,>=1.5 (from pytest>=2.8.1->pytest-logging<2016.0.0,>=2015.11.4->prefixcommons>=0.1.12->linkml-runtime>=1.5.3->oaklib)
#   Using cached pluggy-1.5.0-py3-none-any.whl.metadata (4.8 kB)
# Using cached oaklib-0.6.6-py3-none-any.whl (638 kB)
# Using cached kgcl_rdflib-0.5.0-py3-none-any.whl (34 kB)
# Using cached airium-0.2.6-py3-none-any.whl (13 kB)
# Using cached appdirs-1.4.4-py2.py3-none-any.whl (9.6 kB)
# Using cached class_resolver-0.4.3-py3-none-any.whl (25 kB)
# Using cached curies-0.7.9-py3-none-any.whl (45 kB)
# Using cached defusedxml-0.7.1-py2.py3-none-any.whl (25 kB)
# Using cached eutils-0.6.0-py2.py3-none-any.whl (41 kB)
# Using cached funowl-0.2.3-py3-none-any.whl (51 kB)
# Using cached jsonlines-4.0.0-py3-none-any.whl (8.7 kB)
# Using cached kgcl_schema-0.6.8-py3-none-any.whl (46 kB)
# Using cached linkml_renderer-0.3.0-py3-none-any.whl (25 kB)
# Using cached click-8.1.7-py3-none-any.whl (97 kB)
# Using cached linkml_runtime-1.7.5-py3-none-any.whl (560 kB)
# Using cached ndex2-3.8.0-py2.py3-none-any.whl (76 kB)
# Using cached networkx-3.3-py3-none-any.whl (1.7 MB)
# Using cached ols_client-0.1.4-py3-none-any.whl (10 kB)
# Using cached ontoportal_client-0.0.4-py3-none-any.whl (8.8 kB)
# Using cached prefixmaps-0.2.4-py3-none-any.whl (746 kB)
# Using cached pronto-2.5.7-py2.py3-none-any.whl (61 kB)
# Using cached pydantic-2.7.1-py3-none-any.whl (409 kB)
# Using cached pydantic_core-2.18.2-cp311-cp311-macosx_11_0_arm64.whl (1.8 MB)
# Using cached pystow-0.5.4-py3-none-any.whl (32 kB)
# Using cached requests_cache-1.2.0-py3-none-any.whl (61 kB)
# Using cached semsql-0.3.3-py3-none-any.whl (132 kB)
# Using cached SQLAlchemy-2.0.30-cp311-cp311-macosx_11_0_arm64.whl (2.1 MB)
# Using cached sssom-0.4.9-py3-none-any.whl (167 kB)
# Using cached SPARQLWrapper-2.0.0-py3-none-any.whl (28 kB)
# Using cached tenacity-8.3.0-py3-none-any.whl (25 kB)
# Using cached annotated_types-0.6.0-py3-none-any.whl (12 kB)
# Using cached attrs-23.2.0-py3-none-any.whl (60 kB)
# Using cached cattrs-23.2.3-py3-none-any.whl (57 kB)
# Using cached chardet-5.2.0-py3-none-any.whl (199 kB)
# Using cached deprecation-2.1.0-py2.py3-none-any.whl (11 kB)
# Using cached fastobo-0.12.3-cp311-cp311-macosx_11_0_arm64.whl (1.7 MB)
# Using cached importlib_resources-6.4.0-py3-none-any.whl (38 kB)
# Using cached json_flattener-0.1.9-py3-none-any.whl (10 kB)
# Using cached jsonasobj2-1.0.4-py3-none-any.whl (6.3 kB)
# Using cached jsonschema-4.22.0-py3-none-any.whl (88 kB)
# Using cached lark-1.1.9-py3-none-any.whl (111 kB)
# Using cached pandas-2.2.2-cp311-cp311-macosx_11_0_arm64.whl (11.3 MB)
# Using cached numpy-1.26.4-cp311-cp311-macosx_11_0_arm64.whl (14.0 MB)
# Using cached pansql-0.0.1-py3-none-any.whl (26 kB)
# Using cached prefixcommons-0.1.12-py3-none-any.whl (29 kB)
# Using cached PyJSG-0.11.10-py3-none-any.whl (80 kB)
# Using cached jsonasobj-1.3.1-py3-none-any.whl (4.4 kB)
# Using cached pytz-2024.1-py2.py3-none-any.whl (505 kB)
# Using cached PyYAML-6.0.1-cp311-cp311-macosx_11_0_arm64.whl (167 kB)
# Using cached rdflib-7.0.0-py3-none-any.whl (531 kB)
# Using cached requests-2.31.0-py3-none-any.whl (62 kB)
# Using cached SQLAlchemy_Utils-0.38.3-py3-none-any.whl (100 kB)
# Using cached sssom_schema-0.15.2-py3-none-any.whl (28 kB)
# Using cached url_normalize-1.4.3-py2.py3-none-any.whl (6.8 kB)
# Using cached urllib3-2.2.1-py3-none-any.whl (121 kB)
# Using cached validators-0.28.1-py3-none-any.whl (39 kB)
# Using cached bcp47-0.1.0-py3-none-any.whl (13 kB)
# Using cached Deprecated-1.2.14-py2.py3-none-any.whl (9.6 kB)
# Using cached hbreader-0.9.1-py3-none-any.whl (7.6 kB)
# Using cached ijson-3.2.3-cp311-cp311-macosx_11_0_arm64.whl (54 kB)
# Using cached lxml-5.2.2-cp311-cp311-macosx_10_9_universal2.whl (8.1 MB)
# Using cached more_click-0.1.2-py3-none-any.whl (6.7 kB)
# Using cached PyTrie-0.4.0-py3-none-any.whl (6.1 kB)
# Using cached rdflib_shim-1.0.3-py3-none-any.whl (5.2 kB)
# Using cached rdflib_jsonld-0.6.1-py2.py3-none-any.whl (16 kB)
# Using cached requests_toolbelt-1.0.0-py2.py3-none-any.whl (54 kB)
# Using cached rfc3987-1.3.8-py2.py3-none-any.whl (13 kB)
# Using cached tqdm-4.66.4-py3-none-any.whl (78 kB)
# Using cached certifi-2024.2.2-py3-none-any.whl (163 kB)
# Using cached charset_normalizer-3.3.2-cp311-cp311-macosx_11_0_arm64.whl (118 kB)
# Using cached idna-3.7-py3-none-any.whl (66 kB)
# Using cached isodate-0.6.1-py2.py3-none-any.whl (41 kB)
# Using cached jsonschema_specifications-2023.12.1-py3-none-any.whl (18 kB)
# Using cached pyparsing-3.1.2-py3-none-any.whl (103 kB)
# Using cached referencing-0.35.1-py3-none-any.whl (26 kB)
# Using cached rpds_py-0.18.1-cp311-cp311-macosx_11_0_arm64.whl (322 kB)
# Using cached tzdata-2024.1-py2.py3-none-any.whl (345 kB)
# Using cached wrapt-1.16.0-cp311-cp311-macosx_11_0_arm64.whl (38 kB)
# Using cached scipy-1.13.0-cp311-cp311-macosx_12_0_arm64.whl (30.3 MB)
# Using cached sortedcontainers-2.4.0-py2.py3-none-any.whl (29 kB)
# Using cached pytest-8.2.0-py3-none-any.whl (339 kB)
# Using cached pluggy-1.5.0-py3-none-any.whl (20 kB)
# Using cached iniconfig-2.0.0-py3-none-any.whl (5.9 kB)
# Installing collected packages: sortedcontainers, rfc3987, ratelimit, pytz, jsonasobj, ijson, bcp47, appdirs, antlr4-python3-runtime, airium, wrapt, validators, urllib3, url-normalize, tzdata, tqdm, tenacity, SQLAlchemy, rpds-py, pyyaml, pytrie, pyparsing, pyjsg, pydantic-core, pluggy, numpy, networkx, lxml, lark, isodate, iniconfig, importlib-resources, idna, hbreader, fastobo, deprecation, defusedxml, click, class-resolver, charset-normalizer, chardet, certifi, attrs, annotated-types, SQLAlchemy-Utils, scipy, requests, referencing, rdflib, pytest, pydantic, pronto, pandas, more-click, jsonlines, jsonasobj2, json-flattener, deprecated, cattrs, SPARQLWrapper, requests-toolbelt, requests-cache, rdflib-jsonld, pytest-logging, pystow, pysolr, pansql, jsonschema-specifications, eutils, curies, rdflib-shim, prefixmaps, prefixcommons, ontoportal-client, ols-client, ndex2, jsonschema, linkml-runtime, funowl, sssom-schema, semsql, linkml-renderer, kgcl-schema, sssom, kgcl-rdflib, oaklib
# Successfully installed SPARQLWrapper-2.0.0 SQLAlchemy-2.0.30 SQLAlchemy-Utils-0.38.3 airium-0.2.6 annotated-types-0.6.0 antlr4-python3-runtime-4.9.3 appdirs-1.4.4 attrs-23.2.0 bcp47-0.1.0 cattrs-23.2.3 certifi-2024.2.2 chardet-5.2.0 charset-normalizer-3.3.2 class-resolver-0.4.3 click-8.1.7 curies-0.7.9 defusedxml-0.7.1 deprecated-1.2.14 deprecation-2.1.0 eutils-0.6.0 fastobo-0.12.3 funowl-0.2.3 hbreader-0.9.1 idna-3.7 ijson-3.2.3 importlib-resources-6.4.0 iniconfig-2.0.0 isodate-0.6.1 json-flattener-0.1.9 jsonasobj-1.3.1 jsonasobj2-1.0.4 jsonlines-4.0.0 jsonschema-4.22.0 jsonschema-specifications-2023.12.1 kgcl-rdflib-0.5.0 kgcl-schema-0.6.8 lark-1.1.9 linkml-renderer-0.3.0 linkml-runtime-1.7.5 lxml-5.2.2 more-click-0.1.2 ndex2-3.8.0 networkx-3.3 numpy-1.26.4 oaklib-0.6.6 ols-client-0.1.4 ontoportal-client-0.0.4 pandas-2.2.2 pansql-0.0.1 pluggy-1.5.0 prefixcommons-0.1.12 prefixmaps-0.2.4 pronto-2.5.7 pydantic-2.7.1 pydantic-core-2.18.2 pyjsg-0.11.10 pyparsing-3.1.2 pysolr-3.9.0 pystow-0.5.4 pytest-8.2.0 pytest-logging-2015.11.4 pytrie-0.4.0 pytz-2024.1 pyyaml-6.0.1 ratelimit-2.2.1 rdflib-7.0.0 rdflib-jsonld-0.6.1 rdflib-shim-1.0.3 referencing-0.35.1 requests-2.31.0 requests-cache-1.2.0 requests-toolbelt-1.0.0 rfc3987-1.3.8 rpds-py-0.18.1 scipy-1.13.0 semsql-0.3.3 sortedcontainers-2.4.0 sssom-0.4.9 sssom-schema-0.15.2 tenacity-8.3.0 tqdm-4.66.4 tzdata-2024.1 url-normalize-1.4.3 urllib3-2.2.1 validators-0.28.1 wrapt-1.16.0

# %%
# Load Imports
import pandas as pd
from pathlib import Path
from oaklib import get_adapter
from oaklib.mappers import OntologyMetadataMapper
from oaklib.datamodels.vocabulary import IS_A, PART_OF, SEMAPV, OWL_OBJECT_PROPERTY, OWL_ANNOTATION_PROPERTY
from typing import Tuple, List

# Configure dataframe display
pd.set_option('display.max_columns', None)
# pd.set_option('display.max_rows', None)
pd.set_option('display.max_colwidth', None)
adapter = get_adapter(oak_adapter)

# %% [markdown]
# [Back](#overview)
#
# ---
# <a id="download"></a>
# ### Load Mondo using OAK pronto adapter

# %%
# Let's explore the ontology and get some initial data by getting all children of a class 

# Get all descendants for a CURIE
all_diseases = set(adapter.descendants(["MONDO:0000001"], predicates=[IS_A]))
all_characteristics = set(adapter.descendants(["MONDO:0021125"], predicates=[IS_A]))
all_susceptibilities = set(adapter.descendants(["MONDO:0042489"], predicates=[IS_A]))
all_injuries = set(adapter.descendants(["MONDO:0021178"], predicates=[IS_A]))

all_mondo_terms = {
    "diseases": all_diseases,
    "characteristics": all_characteristics,
    "susceptibilities": all_susceptibilities,
    "injuries": all_injuries
}



def get_subsets(adapter, mondo_terms_by_group: dict[str, List]) -> List[Tuple[str, List[str]]]:
    """Get subsets for a list of descendants.""" 
    data_subsets = []
    for mondo_group, mondo_terms in mondo_terms_by_group.items():    
        for e, subset in sorted(adapter.terms_subsets(mondo_terms)):
            data_subsets.append({
                "id": e,
                "subset": subset,
                "group": mondo_group
            })
    df = pd.DataFrame(data_subsets)
    return df

df_subsets = get_subsets(adapter, all_mondo_terms)
df_subsets.to_csv("mondo_subsets.csv", sep="\t", index=False)
df_subsets
# Out:
#                   id         subset     group
# 0      MONDO:0000004           otar  diseases
# 1      MONDO:0000005  inferred_rare  diseases
# 2      MONDO:0000005           rare  diseases
# 3      MONDO:0000009  inferred_rare  diseases
# 4      MONDO:0000009           otar  diseases
# ...              ...            ...       ...
# 68912  MONDO:0043797   ordo_disease  injuries
# 68913  MONDO:0043797  orphanet_rare  injuries
# 68914  MONDO:0043797           rare  injuries
# 68915  MONDO:0044745           otar  injuries
# 68916  MONDO:0100075           otar  injuries
#
# [68917 rows x 3 columns]

# %%
def get_synonyms(adapter, mondo_terms_by_group: dict[str, List]) -> List[Tuple[str, List[str]]]:
    """Get subsets for a list of descendants.""" 
    data_subsets = []
    for mondo_group, mondo_terms in mondo_terms_by_group.items():    
        for entity, spv in adapter.synonym_property_values(mondo_terms):
            xrefs = "|".join(spv.xrefs)
            synonym_type = spv.synonymType
            synonym = spv.val
            predicate = spv.pred
            data_subsets.append({
                "id": entity,
                "synonym": synonym,
                "synonym_type": synonym_type,
                "xrefs": xrefs,
                "predicate": predicate,
                "group": mondo_group
            })
    df = pd.DataFrame(data_subsets)
    return df

#all_mondo_terms
df_synonyms = get_synonyms(adapter, {"disease":["MONDO:0000001"]})
df_synonyms.to_csv("mondo_synonyms.csv", sep="\t", index=False)
df_synonyms
# Out:
#               id                              synonym synonym_type  \
# 0  MONDO:0000001                            condition         None
# 1  MONDO:0000001                              disease         None
# 2  MONDO:0000001                  disease or disorder         None
# 3  MONDO:0000001  disease or disorder, non-neoplastic         None
# 4  MONDO:0000001                             diseases         None
# 5  MONDO:0000001               diseases and disorders         None
# 6  MONDO:0000001                             disorder         None
# 7  MONDO:0000001                            disorders         None
# 8  MONDO:0000001                    medical condition         None
# 9  MONDO:0000001                        other disease         None
#
#         xrefs        predicate    group
# 0  NCIT:C2991  hasExactSynonym  disease
# 1  NCIT:C2991  hasExactSynonym  disease
# 2  NCIT:C2991  hasExactSynonym  disease
# 3  NCIT:C2991  hasExactSynonym  disease
# 4  NCIT:C2991  hasExactSynonym  disease
# 5  NCIT:C2991  hasExactSynonym  disease
# 6  NCIT:C2991  hasExactSynonym  disease
# 7  NCIT:C2991  hasExactSynonym  disease
# 8              hasExactSynonym  disease
# 9  NCIT:C2991  hasExactSynonym  disease
