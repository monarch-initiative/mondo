# %%
# %reset -f

# %% [markdown]
# # Code examples interacting with Mondo

# %% [markdown]
# ## Install oaklib
#  - Installation of oaklib can be found in the [documentation here](https://incatools.github.io/ontology-access-kit/intro/tutorial01.html)

# %%
from pathlib import Path
from oaklib import get_adapter
from oaklib.datamodels.vocabulary import IS_A, PART_OF, SEMAPV
import pandas as pd
import curies
import llm
import re
import logging
import json

### LOGGING SETTINGS
logger = logging.getLogger()
logger.setLevel(logging.CRITICAL)
logging.getLogger().addHandler(logging.NullHandler())

### LOAD OTHER LIBRARIES
converter = curies.get_obo_converter()

### LLM SETTINGS

print(response.text())

### LOAD MONDO
mondo = get_adapter(f"sqlite:obo:mondo")
# Out:
# 1. Captain Quackbeak
# 2. Salty Splashguzzle
# 3. Sir Fishington Wingwater
# 4. Priscilla Pouchface
# 5. Commodore Airscoop

# %%
map_rels_to_labels = {
    'rdfs:subClassOf': 'is a subclass',
    'RO:0004029': 'is associated with a phenotype',
}

branch = "MONDO:0018076"

df = review_relationships_in_branch(branch, prompt_review_rels, mondo, ct=1, map_rels_to_labels=map_rels_to_labels)
df.to_csv("../../ontology/reports/mondo_subclass_review.tsv", index=False, sep="\t")
# Out:
# 1: {'assessment': 'yes', 'confidence': 1.0, 'explanation of assessment': 'Tuberculous epididymitis (MONDO:0001537) is a specific type of epididymitis (MONDO:0004779) caused by tuberculosis. Hence, it is a subclass of epididymitis. The relationship_id is rdfs:subClassOf.', 'disease_id': 'MONDO:0001537', 'disease_name': 'tuberculous epididymitis', 'relationship': 'rdfs:subClassOf', 'related_entity_id': 'MONDO:0004779', 'related_entity_name': 'epididymitis'}

# %%
branches = []
for branch in mondo.incoming_relationships("MONDO:0700096", predicates=["rdfs:subClassOf"]):
    branches.append(branch[1])
print(len(branches))
# Out:
# 41

# %%
df_bm = review_branch_membership("MONDO:0018076", prompt_review_branches, prompt_branch_member, mondo, branches_map_labels, ct=20)
df_bm.to_csv("../../ontology/reports/mondo_branch_review.tsv", index=False, sep="\t")
df_bm
# Out:
# 18: {'disease_id': 'MONDO:0001537', 'disease_name': 'tuberculous epididymitis', 'branch_ancestor_id': 'MONDO:0021166', 'branch_ancestor_name': 'inflammatory disease', 'confirmation_status': 'only mondo', 'confidence': 0.9, 'explanation of grouping': 'WARNING: the LLM did not consider this grouping during the previous question. The explanation of the of the grouping is: Tuberculous epididymitis is a condition where the epididymis - a tube located at the back of the testicles that stores and carries sperm - becomes inflamed due to a tuberculosis infection. Therefore, it can be considered a type of inflammatory disease, which is generally characterized as a response by the body’s immune system to infection or injury resulting in inflammation or swelling.'}
# 18: {'disease_id': 'MONDO:0001537', 'disease_name': 'tuberculous epididymitis', 'branch_ancestor_id': 'MONDO:0021669', 'branch_ancestor_name': 'post-infectious disorder', 'confirmation_status': 'only gpt', 'confidence': 0.7, 'explanation of grouping': 'In some cases, tuberculous epididymitis can occur after an individual has had tuberculosis, making it potentially a post-infectious disorder.'}
# 18: {'disease_id': 'MONDO:0001537', 'disease_name': 'tuberculous epididymitis', 'branch_ancestor_id': 'MONDO:0005550', 'branch_ancestor_name': 'infectious disease', 'confirmation_status': 'in both', 'confidence': 1, 'explanation of grouping': 'Tuberculous epididymitis is caused by Mycobacterium tuberculosis, making it an infectious disease.'}
# 18: {'disease_id': 'MONDO:0001537', 'disease_name': 'tuberculous epididymitis', 'branch_ancestor_id': 'MONDO:0005039', 'branch_ancestor_name': 'reproductive system disorder', 'confirmation_status': 'in both', 'confidence': 1, 'explanation of grouping': 'The disease affects the epididymis, a part of the male reproductive system, thus it should be grouped as a reproductive system disorder.'}
# 16: {'disease_id': 'MONDO:0005999', 'disease_name': 'tuberculous empyema', 'branch_ancestor_id': 'MONDO:0021166', 'branch_ancestor_name': 'inflammatory disease', 'confirmation_status': 'only mondo', 'confidence': 0.9, 'explanation of grouping': 'WARNING: the LLM did not consider this grouping during the previous question. The explanation of the of the grouping is: Tuberculous empyema is a condition where the pleural space is infected by tuberculosis causing an accumulation of pus, leading to inflammation. Thus, considering the fact that it causes inflammation, tuberculous empyema can be considered as a type of inflammatory disease.'}
# 16: {'disease_id': 'MONDO:0005999', 'disease_name': 'tuberculous empyema', 'branch_ancestor_id': 'MONDO:0005087', 'branch_ancestor_name': 'respiratory system disorder', 'confirmation_status': 'in both', 'confidence': 1, 'explanation of grouping': 'Tuberculous empyema is a condition related to the lungs, where pus accumulates within a naturally existing anatomical cavity. This clearly falls under respiratory diseases.'}
# 16: {'disease_id': 'MONDO:0005999', 'disease_name': 'tuberculous empyema', 'branch_ancestor_id': 'MONDO:0021669', 'branch_ancestor_name': 'post-infectious disorder', 'confirmation_status': 'only gpt', 'confidence': 0.7, 'explanation of grouping': 'Tuberculous empyema is a condition that occurs secondary to a pulmonary tuberculosis infection. Therefore, it could be categorized as a post-infectious condition.'}
# 16: {'disease_id': 'MONDO:0005999', 'disease_name': 'tuberculous empyema', 'branch_ancestor_id': 'MONDO:0005550', 'branch_ancestor_name': 'infectious disease', 'confirmation_status': 'in both', 'confidence': 1, 'explanation of grouping': 'Tuberculous empyema is caused by tuberculosis, which is an infectious disease. Thus, it belongs in the infectious disease group.'}
# 15: {'disease_id': 'MONDO:0005861', 'disease_name': 'multidrug-resistant tuberculosis', 'branch_ancestor_id': 'MONDO:0005046', 'branch_ancestor_name': 'immune system disorder', 'confirmation_status': 'only gpt', 'confidence': 0.7, 'explanation of grouping': 'While it is foremost an infectious disease, tuberculosis is also considered an immune system disorder because the progression of the disease is largely dependent on the immune response of the infected individual.'}
# 15: {'disease_id': 'MONDO:0005861', 'disease_name': 'multidrug-resistant tuberculosis', 'branch_ancestor_id': 'MONDO:0005087', 'branch_ancestor_name': 'respiratory system disorder', 'confirmation_status': 'only gpt', 'confidence': 1, 'explanation of grouping': 'Tuberculosis primarily affects the lungs, which are part of the respiratory system, therefore it is a respiratory system disorder.'}
# 15: {'disease_id': 'MONDO:0005861', 'disease_name': 'multidrug-resistant tuberculosis', 'branch_ancestor_id': 'MONDO:0021669', 'branch_ancestor_name': 'post-infectious disorder', 'confirmation_status': 'only gpt', 'confidence': 0.6, 'explanation of grouping': 'Since multidrug-resistant tuberculosis is an advancement from initial tuberculosis infection, it could be considered a post-infectious disorder, specifically post-tuberculosis.'}
# 15: {'disease_id': 'MONDO:0005861', 'disease_name': 'multidrug-resistant tuberculosis', 'branch_ancestor_id': 'MONDO:0005550', 'branch_ancestor_name': 'infectious disease', 'confirmation_status': 'in both', 'confidence': 1, 'explanation of grouping': 'Multidrug-resistant tuberculosis is caused by Mycobacterium tuberculosis that is resistant to at least two of the main first-line anti-tuberculosis drugs. This makes it an infectious disease.'}
# 14: {'disease_id': 'MONDO:0006000', 'disease_name': 'tuberculous peritonitis', 'branch_ancestor_id': 'MONDO:0021166', 'branch_ancestor_name': 'inflammatory disease', 'confirmation_status': 'in both', 'confidence': 1, 'explanation of grouping': 'Tuberculous peritonitis involves inflammation of the peritoneum, so it is considered an inflammatory disease.'}
# 14: {'disease_id': 'MONDO:0006000', 'disease_name': 'tuberculous peritonitis', 'branch_ancestor_id': 'MONDO:0004335', 'branch_ancestor_name': 'digestive system disorder', 'confirmation_status': 'in both', 'confidence': 1, 'explanation of grouping': 'Tuberculous peritonitis involves the inflammation of the peritoneum, which is a layer of the abdominal cavity. Therefore, it falls under the category of digestive system disorders.'}
# 14: {'disease_id': 'MONDO:0006000', 'disease_name': 'tuberculous peritonitis', 'branch_ancestor_id': 'MONDO:0005550', 'branch_ancestor_name': 'infectious disease', 'confirmation_status': 'in both', 'confidence': 1, 'explanation of grouping': 'Tuberculous peritonitis is caused by the bacterium Mycobacterium tuberculosis, which makes it an infectious disease.'}
# 13: {'disease_id': 'MONDO:0006052', 'disease_name': 'pulmonary tuberculosis', 'branch_ancestor_id': 'MONDO:0005087', 'branch_ancestor_name': 'respiratory system disorder', 'confirmation_status': 'in both', 'confidence': 1, 'explanation of grouping': 'Pulmonary tuberculosis primarily affects the lungs, which are part of the respiratory system.'}
# 13: {'disease_id': 'MONDO:0006052', 'disease_name': 'pulmonary tuberculosis', 'branch_ancestor_id': 'MONDO:0021669', 'branch_ancestor_name': 'post-infectious disorder', 'confirmation_status': 'only gpt', 'confidence': 0.85, 'explanation of grouping': 'Pulmonary tuberculosis can lead to long-term lung damage, making it a post-infectious disorder.'}
# 13: {'disease_id': 'MONDO:0006052', 'disease_name': 'pulmonary tuberculosis', 'branch_ancestor_id': 'MONDO:0005550', 'branch_ancestor_name': 'infectious disease', 'confirmation_status': 'in both', 'confidence': 1, 'explanation of grouping': 'Pulmonary tuberculosis is caused by the Mycobacterium tuberculosis bacteria, which makes it an infectious disease.'}
# 12: {'disease_id': 'MONDO:0005962', 'disease_name': 'skeletal tuberculosis', 'branch_ancestor_id': 'MONDO:0002081', 'branch_ancestor_name': 'musculoskeletal system disorder', 'confirmation_status': 'in both', 'confidence': 1, 'explanation of grouping': 'Skeletal Tuberculosis involves the skeletal system, indicating that it should be classified as a musculoskeletal disorder.'}
# 12: {'disease_id': 'MONDO:0005962', 'disease_name': 'skeletal tuberculosis', 'branch_ancestor_id': 'MONDO:0021669', 'branch_ancestor_name': 'post-infectious disorder', 'confirmation_status': 'only gpt', 'confidence': 0.8, 'explanation of grouping': 'Skeletal Tuberculosis may be considered a post-infectious disorder as it occurs as a result of the tuberculosis infection.'}
# 12: {'disease_id': 'MONDO:0005962', 'disease_name': 'skeletal tuberculosis', 'branch_ancestor_id': 'MONDO:0005550', 'branch_ancestor_name': 'infectious disease', 'confirmation_status': 'in both', 'confidence': 1, 'explanation of grouping': 'Skeletal Tuberculosis is a form of tuberculosis, which is an infectious disease caused by bacteria.'}
# 10: {'disease_id': 'MONDO:0005903', 'disease_name': 'pericardial tuberculosis', 'branch_ancestor_id': 'MONDO:0021166', 'branch_ancestor_name': 'inflammatory disease', 'confirmation_status': 'only mondo', 'confidence': 0.9, 'explanation of grouping': 'WARNING: the LLM did not consider this grouping during the previous question. The explanation of the of the grouping is: Pericardial tuberculosis is an infection of the pericardium (the protective sac around the heart) caused by the Mycobacterium tuberculosis bacterium. This infection causes inflammation of the pericardium, which classifies it as an inflammatory disease. Therefore, it should be grouped under Inflammatory diseases in an ontology using the subclass relation.'}
# 10: {'disease_id': 'MONDO:0005903', 'disease_name': 'pericardial tuberculosis', 'branch_ancestor_id': 'MONDO:0004995', 'branch_ancestor_name': 'cardiovascular disorder', 'confirmation_status': 'in both', 'confidence': 0.95, 'explanation of grouping': 'Pericardial tuberculosis affects the pericardium, which is a part of the cardiovascular system. Hence it can also be grouped under cardiovascular disorder.'}
# 10: {'disease_id': 'MONDO:0005903', 'disease_name': 'pericardial tuberculosis', 'branch_ancestor_id': 'MONDO:0005550', 'branch_ancestor_name': 'infectious disease', 'confirmation_status': 'in both', 'confidence': 1, 'explanation of grouping': 'Pericardial tuberculosis is an inflammatory condition of pericardium caused by Mycobacterium tuberculosis, a bacteria. Hence, it falls under the category of infectious diseases.'}
# 9: {'disease_id': 'MONDO:0006838', 'disease_name': 'lupus vulgaris', 'branch_ancestor_id': 'MONDO:0005046', 'branch_ancestor_name': 'immune system disorder', 'confirmation_status': 'only gpt', 'confidence': 0.95, 'explanation of grouping': 'Lupus vulgaris is a form of cutaneous tuberculosis that results from an immune response to Mycobacterium tuberculosis.'}
# 9: {'disease_id': 'MONDO:0006838', 'disease_name': 'lupus vulgaris', 'branch_ancestor_id': 'MONDO:0005550', 'branch_ancestor_name': 'infectious disease', 'confirmation_status': 'in both', 'confidence': 0.9, 'explanation of grouping': 'Lupus Vulgaris is caused by the Mycobacterium tuberculosis bacteria, classifying it as an infectious disease.'}
# 9: {'disease_id': 'MONDO:0006838', 'disease_name': 'lupus vulgaris', 'branch_ancestor_id': 'MONDO:0002051', 'branch_ancestor_name': 'integumentary system disorder', 'confirmation_status': 'only gpt', 'confidence': 0.85, 'explanation of grouping': 'This condition manifests as lesions on the skin, suggesting it can be grouped under disorders of the integumentary system.'}
# 8: {'disease_id': 'MONDO:0000070', 'disease_name': 'mycobacterium tuberculosis, susceptibility', 'branch_ancestor_id': 'MONDO:0005046', 'branch_ancestor_name': 'immune system disorder', 'confirmation_status': 'only gpt', 'confidence': 0.7, 'explanation of grouping': 'The susceptibility to Mycobacterium tuberculosis can be linked to the state of the immune system, indicating an involvement of the immune system disorder group.'}
# 8: {'disease_id': 'MONDO:0000070', 'disease_name': 'mycobacterium tuberculosis, susceptibility', 'branch_ancestor_id': 'MONDO:0005550', 'branch_ancestor_name': 'infectious disease', 'confirmation_status': 'in both', 'confidence': 1, 'explanation of grouping': 'Mycobacterium tuberculosis is a bacterial disease causing infection, placing it under the infectious disease grouping.'}
# 8: {'disease_id': 'MONDO:0000070', 'disease_name': 'mycobacterium tuberculosis, susceptibility', 'branch_ancestor_id': 'MONDO:0005087', 'branch_ancestor_name': 'respiratory system disorder', 'confirmation_status': 'only gpt', 'confidence': 0.9, 'explanation of grouping': 'This disease primarily affects the respiratory system, specifically it can cause Tuberculosis which primarily affect the lungs.'}
# 6: {'disease_id': 'MONDO:0000271', 'disease_name': 'tuberculous salpingitis', 'branch_ancestor_id': 'MONDO:0005046', 'branch_ancestor_name': 'immune system disorder', 'confirmation_status': 'only gpt', 'confidence': 0.7, 'explanation of grouping': "Infection with Mycobacterium tuberculosis can trigger an immune response, potentially causing damage to the host's tissues. However, not all cases lead to noticeable immune system disorder."}
# 6: {'disease_id': 'MONDO:0000271', 'disease_name': 'tuberculous salpingitis', 'branch_ancestor_id': 'MONDO:0021166', 'branch_ancestor_name': 'inflammatory disease', 'confirmation_status': 'only mondo', 'confidence': 0.95, 'explanation of grouping': 'WARNING: the LLM did not consider this grouping during the previous question. The explanation of the of the grouping is: Tuberculous salpingitis is an inflammatory disease of the fallopian tubes caused by Mycobacterium tuberculosis. Inflammatory diseases are diseases characterized by inflammation and tuberculosis in any body organ leads to inflammation of that organ. Therefore, Tuberculous salpingitis can be considered a type of inflammatory disease.'}
# 6: {'disease_id': 'MONDO:0000271', 'disease_name': 'tuberculous salpingitis', 'branch_ancestor_id': 'MONDO:0005550', 'branch_ancestor_name': 'infectious disease', 'confirmation_status': 'in both', 'confidence': 1, 'explanation of grouping': 'Tuberculous salpingitis is caused by the bacterium Mycobacterium tuberculosis, which makes it an infectious disease.'}
# 6: {'disease_id': 'MONDO:0000271', 'disease_name': 'tuberculous salpingitis', 'branch_ancestor_id': 'MONDO:0005039', 'branch_ancestor_name': 'reproductive system disorder', 'confirmation_status': 'in both', 'confidence': 1, 'explanation of grouping': 'Salpingitis is an inflammation of the fallopian tubes, which are a part of the female reproductive system.'}
# 5: {'disease_id': 'MONDO:0006876', 'disease_name': 'ocular tuberculosis', 'branch_ancestor_id': 'MONDO:0024458', 'branch_ancestor_name': 'disorder of visual system', 'confirmation_status': 'in both', 'confidence': 0.9, 'explanation of grouping': "The disease directly affects part of the vision system - the eye. Hence, it can be classified under 'disorder of visual system'."}
# 5: {'disease_id': 'MONDO:0006876', 'disease_name': 'ocular tuberculosis', 'branch_ancestor_id': 'MONDO:0021669', 'branch_ancestor_name': 'post-infectious disorder', 'confirmation_status': 'only gpt', 'confidence': 0.5, 'explanation of grouping': 'While primary infections can cause ocular tuberculosis, it is often seen as a manifestation following an infection elsewhere in the body, such as the lungs.'}
# 5: {'disease_id': 'MONDO:0006876', 'disease_name': 'ocular tuberculosis', 'branch_ancestor_id': 'MONDO:0005550', 'branch_ancestor_name': 'infectious disease', 'confirmation_status': 'in both', 'confidence': 1.0, 'explanation of grouping': 'Ocular tuberculosis is clearly an infection, caused by the bacteria Mycobacterium tuberculosis.'}
# 5: {'disease_id': 'MONDO:0006876', 'disease_name': 'ocular tuberculosis', 'branch_ancestor_id': 'MONDO:0002022', 'branch_ancestor_name': 'disorder of orbital region', 'confirmation_status': 'in both', 'confidence': 0.7, 'explanation of grouping': "Ocular tuberculosis can affect structures around the eye, which may justify its inclusion under 'disorder of orbital region'."}
# 4: {'disease_id': 'MONDO:0043836', 'disease_name': 'tuberculosis, spinal', 'branch_ancestor_id': 'MONDO:0002081', 'branch_ancestor_name': 'musculoskeletal system disorder', 'confirmation_status': 'in both', 'confidence': 0.75, 'explanation of grouping': 'Spinal tuberculosis, as indicated by its name, is a manifestation of tuberculosis affecting the spine, indicating involvement of the musculoskeletal system.'}
# 4: {'disease_id': 'MONDO:0043836', 'disease_name': 'tuberculosis, spinal', 'branch_ancestor_id': 'MONDO:0021669', 'branch_ancestor_name': 'post-infectious disorder', 'confirmation_status': 'only gpt', 'confidence': 0.65, 'explanation of grouping': 'Tuberculosis can persist as a latent infection or can result in long lasting complications, making it a post-infectious disorder.'}
# 4: {'disease_id': 'MONDO:0043836', 'disease_name': 'tuberculosis, spinal', 'branch_ancestor_id': 'MONDO:0005550', 'branch_ancestor_name': 'infectious disease', 'confirmation_status': 'in both', 'confidence': 0.99, 'explanation of grouping': 'Tuberculosis is an infectious disease caused by the bacterium Mycobacterium tuberculosis.'}
# 4: {'disease_id': 'MONDO:0043836', 'disease_name': 'tuberculosis, spinal', 'branch_ancestor_id': 'MONDO:0005087', 'branch_ancestor_name': 'respiratory system disorder', 'confirmation_status': 'only gpt', 'confidence': 0.85, 'explanation of grouping': 'The primary site of infection for tuberculosis is the lungs, making it a disorder of the respiratory system; however, tuberculosis can disseminate to other parts of body.'}
# 2: {'disease_id': 'MONDO:0005819', 'disease_name': 'laryngeal tuberculosis', 'branch_ancestor_id': 'MONDO:0021166', 'branch_ancestor_name': 'inflammatory disease', 'confirmation_status': 'only mondo', 'confidence': 0.9, 'explanation of grouping': 'WARNING: the LLM did not consider this grouping during the previous question. The explanation of the of the grouping is: Laryngeal tuberculosis is a form of tuberculosis that infects the larynx. Tuberculosis is caused by Mycobacterium tuberculosis, which leads to an inflammatory response in the body as part of the immune response. Thus, laryngeal tuberculosis can be categorized as a type of inflammatory disease, but it is also a type of infectious disease.'}
# 2: {'disease_id': 'MONDO:0005819', 'disease_name': 'laryngeal tuberculosis', 'branch_ancestor_id': 'MONDO:0005087', 'branch_ancestor_name': 'respiratory system disorder', 'confirmation_status': 'in both', 'confidence': 1, 'explanation of grouping': 'Laryngeal tuberculosis affects the larynx which is part of the respiratory system.'}
# 2: {'disease_id': 'MONDO:0005819', 'disease_name': 'laryngeal tuberculosis', 'branch_ancestor_id': 'MONDO:0005550', 'branch_ancestor_name': 'infectious disease', 'confirmation_status': 'in both', 'confidence': 1, 'explanation of grouping': 'Laryngeal tuberculosis is a form of tuberculosis, an infectious disease caused by the bacteria Mycobacterium tuberculosis.'}
# 2: {'disease_id': 'MONDO:0005819', 'disease_name': 'laryngeal tuberculosis', 'branch_ancestor_id': 'MONDO:0024623', 'branch_ancestor_name': 'otorhinolaryngologic disease', 'confirmation_status': 'only gpt', 'confidence': 0.95, 'explanation of grouping': 'Laryngeal tuberculosis is a condition that affects the larynx which is part of the orotrhinolaryngologic system, although it is primarily classified as a respiratory disease.'}
# 1: {'disease_id': 'MONDO:0004272', 'disease_name': 'urinary bladder tuberculosis', 'branch_ancestor_id': 'MONDO:0021166', 'branch_ancestor_name': 'inflammatory disease', 'confirmation_status': 'only gpt', 'confidence': 0.7, 'explanation of grouping': 'Tuberculosis is known to cause inflammation in the affected area, which in this case is the urinary bladder.'}
# 1: {'disease_id': 'MONDO:0004272', 'disease_name': 'urinary bladder tuberculosis', 'branch_ancestor_id': 'MONDO:0021669', 'branch_ancestor_name': 'post-infectious disorder', 'confirmation_status': 'only gpt', 'confidence': 0.8, 'explanation of grouping': 'Urinary bladder tuberculosis may occur after a person is infected with tuberculosis elsewhere in their body, and the infection spreads to the urinary bladder.'}
# 1: {'disease_id': 'MONDO:0004272', 'disease_name': 'urinary bladder tuberculosis', 'branch_ancestor_id': 'MONDO:0005550', 'branch_ancestor_name': 'infectious disease', 'confirmation_status': 'in both', 'confidence': 1, 'explanation of grouping': 'Tuberculosis is caused by the bacteria Mycobacterium tuberculosis, thus it is classified under infectious diseases.'}
# 1: {'disease_id': 'MONDO:0004272', 'disease_name': 'urinary bladder tuberculosis', 'branch_ancestor_id': 'MONDO:0002118', 'branch_ancestor_name': 'urinary system disorder', 'confirmation_status': 'in both', 'confidence': 1, 'explanation of grouping': 'Urinary bladder tuberculosis is an infection specifically affecting the bladder, which makes it a disease of the urinary system.'}
#        disease_id                                disease_name  \
# 0   MONDO:0001537                    tuberculous epididymitis
# 1   MONDO:0001537                    tuberculous epididymitis
# 2   MONDO:0001537                    tuberculous epididymitis
# 3   MONDO:0001537                    tuberculous epididymitis
# 4   MONDO:0005999                         tuberculous empyema
# 5   MONDO:0005999                         tuberculous empyema
# 6   MONDO:0005999                         tuberculous empyema
# 7   MONDO:0005999                         tuberculous empyema
# 8   MONDO:0005861            multidrug-resistant tuberculosis
# 9   MONDO:0005861            multidrug-resistant tuberculosis
# 10  MONDO:0005861            multidrug-resistant tuberculosis
# 11  MONDO:0005861            multidrug-resistant tuberculosis
# 12  MONDO:0006000                     tuberculous peritonitis
# 13  MONDO:0006000                     tuberculous peritonitis
# 14  MONDO:0006000                     tuberculous peritonitis
# 15  MONDO:0006052                      pulmonary tuberculosis
# 16  MONDO:0006052                      pulmonary tuberculosis
# 17  MONDO:0006052                      pulmonary tuberculosis
# 18  MONDO:0005962                       skeletal tuberculosis
# 19  MONDO:0005962                       skeletal tuberculosis
# 20  MONDO:0005962                       skeletal tuberculosis
# 21  MONDO:0005903                    pericardial tuberculosis
# 22  MONDO:0005903                    pericardial tuberculosis
# 23  MONDO:0005903                    pericardial tuberculosis
# 24  MONDO:0006838                              lupus vulgaris
# 25  MONDO:0006838                              lupus vulgaris
# 26  MONDO:0006838                              lupus vulgaris
# 27  MONDO:0000070  mycobacterium tuberculosis, susceptibility
# 28  MONDO:0000070  mycobacterium tuberculosis, susceptibility
# 29  MONDO:0000070  mycobacterium tuberculosis, susceptibility
# 30  MONDO:0000271                     tuberculous salpingitis
# 31  MONDO:0000271                     tuberculous salpingitis
# 32  MONDO:0000271                     tuberculous salpingitis
# 33  MONDO:0000271                     tuberculous salpingitis
# 34  MONDO:0006876                         ocular tuberculosis
# 35  MONDO:0006876                         ocular tuberculosis
# 36  MONDO:0006876                         ocular tuberculosis
# 37  MONDO:0006876                         ocular tuberculosis
# 38  MONDO:0043836                        tuberculosis, spinal
# 39  MONDO:0043836                        tuberculosis, spinal
# 40  MONDO:0043836                        tuberculosis, spinal
# 41  MONDO:0043836                        tuberculosis, spinal
# 42  MONDO:0005819                      laryngeal tuberculosis
# 43  MONDO:0005819                      laryngeal tuberculosis
# 44  MONDO:0005819                      laryngeal tuberculosis
# 45  MONDO:0005819                      laryngeal tuberculosis
# 46  MONDO:0004272                urinary bladder tuberculosis
# 47  MONDO:0004272                urinary bladder tuberculosis
# 48  MONDO:0004272                urinary bladder tuberculosis
# 49  MONDO:0004272                urinary bladder tuberculosis
#
#    branch_ancestor_id             branch_ancestor_name confirmation_status  \
# 0       MONDO:0021166             inflammatory disease          only mondo
# 1       MONDO:0021669         post-infectious disorder            only gpt
# 2       MONDO:0005550               infectious disease             in both
# 3       MONDO:0005039     reproductive system disorder             in both
# 4       MONDO:0021166             inflammatory disease          only mondo
# 5       MONDO:0005087      respiratory system disorder             in both
# 6       MONDO:0021669         post-infectious disorder            only gpt
# 7       MONDO:0005550               infectious disease             in both
# 8       MONDO:0005046           immune system disorder            only gpt
# 9       MONDO:0005087      respiratory system disorder            only gpt
# 10      MONDO:0021669         post-infectious disorder            only gpt
# 11      MONDO:0005550               infectious disease             in both
# 12      MONDO:0021166             inflammatory disease             in both
# 13      MONDO:0004335        digestive system disorder             in both
# 14      MONDO:0005550               infectious disease             in both
# 15      MONDO:0005087      respiratory system disorder             in both
# 16      MONDO:0021669         post-infectious disorder            only gpt
# 17      MONDO:0005550               infectious disease             in both
# 18      MONDO:0002081  musculoskeletal system disorder             in both
# 19      MONDO:0021669         post-infectious disorder            only gpt
# 20      MONDO:0005550               infectious disease             in both
# 21      MONDO:0021166             inflammatory disease          only mondo
# 22      MONDO:0004995          cardiovascular disorder             in both
# 23      MONDO:0005550               infectious disease             in both
# 24      MONDO:0005046           immune system disorder            only gpt
# 25      MONDO:0005550               infectious disease             in both
# 26      MONDO:0002051    integumentary system disorder            only gpt
# 27      MONDO:0005046           immune system disorder            only gpt
# 28      MONDO:0005550               infectious disease             in both
# 29      MONDO:0005087      respiratory system disorder            only gpt
# 30      MONDO:0005046           immune system disorder            only gpt
# 31      MONDO:0021166             inflammatory disease          only mondo
# 32      MONDO:0005550               infectious disease             in both
# 33      MONDO:0005039     reproductive system disorder             in both
# 34      MONDO:0024458        disorder of visual system             in both
# 35      MONDO:0021669         post-infectious disorder            only gpt
# 36      MONDO:0005550               infectious disease             in both
# 37      MONDO:0002022       disorder of orbital region             in both
# 38      MONDO:0002081  musculoskeletal system disorder             in both
# 39      MONDO:0021669         post-infectious disorder            only gpt
# 40      MONDO:0005550               infectious disease             in both
# 41      MONDO:0005087      respiratory system disorder            only gpt
# 42      MONDO:0021166             inflammatory disease          only mondo
# 43      MONDO:0005087      respiratory system disorder             in both
# 44      MONDO:0005550               infectious disease             in both
# 45      MONDO:0024623     otorhinolaryngologic disease            only gpt
# 46      MONDO:0021166             inflammatory disease            only gpt
# 47      MONDO:0021669         post-infectious disorder            only gpt
# 48      MONDO:0005550               infectious disease             in both
# 49      MONDO:0002118          urinary system disorder             in both
#
#     confidence                            explanation of grouping
# 0         0.90  WARNING: the LLM did not consider this groupin...
# 1         0.70  In some cases, tuberculous epididymitis can oc...
# 2         1.00  Tuberculous epididymitis is caused by Mycobact...
# 3         1.00  The disease affects the epididymis, a part of ...
# 4         0.90  WARNING: the LLM did not consider this groupin...
# 5         1.00  Tuberculous empyema is a condition related to ...
# 6         0.70  Tuberculous empyema is a condition that occurs...
# 7         1.00  Tuberculous empyema is caused by tuberculosis,...
# 8         0.70  While it is foremost an infectious disease, tu...
# 9         1.00  Tuberculosis primarily affects the lungs, whic...
# 10        0.60  Since multidrug-resistant tuberculosis is an a...
# 11        1.00  Multidrug-resistant tuberculosis is caused by ...
# 12        1.00  Tuberculous peritonitis involves inflammation ...
# 13        1.00  Tuberculous peritonitis involves the inflammat...
# 14        1.00  Tuberculous peritonitis is caused by the bacte...
# 15        1.00  Pulmonary tuberculosis primarily affects the l...
# 16        0.85  Pulmonary tuberculosis can lead to long-term l...
# 17        1.00  Pulmonary tuberculosis is caused by the Mycoba...
# 18        1.00  Skeletal Tuberculosis involves the skeletal sy...
# 19        0.80  Skeletal Tuberculosis may be considered a post...
# 20        1.00  Skeletal Tuberculosis is a form of tuberculosi...
# 21        0.90  WARNING: the LLM did not consider this groupin...
# 22        0.95  Pericardial tuberculosis affects the pericardi...
# 23        1.00  Pericardial tuberculosis is an inflammatory co...
# 24        0.95  Lupus vulgaris is a form of cutaneous tubercul...
# 25        0.90  Lupus Vulgaris is caused by the Mycobacterium ...
# 26        0.85  This condition manifests as lesions on the ski...
# 27        0.70  The susceptibility to Mycobacterium tuberculos...
# 28        1.00  Mycobacterium tuberculosis is a bacterial dise...
# 29        0.90  This disease primarily affects the respiratory...
# 30        0.70  Infection with Mycobacterium tuberculosis can ...
# 31        0.95  WARNING: the LLM did not consider this groupin...
# 32        1.00  Tuberculous salpingitis is caused by the bacte...
# 33        1.00  Salpingitis is an inflammation of the fallopia...
# 34        0.90  The disease directly affects part of the visio...
# 35        0.50  While primary infections can cause ocular tube...
# 36        1.00  Ocular tuberculosis is clearly an infection, c...
# 37        0.70  Ocular tuberculosis can affect structures arou...
# 38        0.75  Spinal tuberculosis, as indicated by its name,...
# 39        0.65  Tuberculosis can persist as a latent infection...
# 40        0.99  Tuberculosis is an infectious disease caused b...
# 41        0.85  The primary site of infection for tuberculosis...
# 42        0.90  WARNING: the LLM did not consider this groupin...
# 43        1.00  Laryngeal tuberculosis affects the larynx whic...
# 44        1.00  Laryngeal tuberculosis is a form of tuberculos...
# 45        0.95  Laryngeal tuberculosis is a condition that aff...
# 46        0.70  Tuberculosis is known to cause inflammation in...
# 47        0.80  Urinary bladder tuberculosis may occur after a...
# 48        1.00  Tuberculosis is caused by the bacteria Mycobac...
# 49        1.00  Urinary bladder tuberculosis is an infection s...

# %%
data
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /Users/matentzn/ws/mondo/src/scripts/notebooks/mondo-gpt.ipynb Cell 12 line 1
# ----> <a href='vscode-notebook-cell:/Users/matentzn/ws/mondo/src/scripts/notebooks/mondo-gpt.ipynb#X20sZmlsZQ%3D%3D?line=0'>1</a> data
#
# NameError: name 'data' is not defined
